# %%
# from sklearn.datasets import load_boston
# b_data = load_boston()
# 不知道怎么导入只能用csv文件了QAQ
import pandas as pd
b_data = pd.read_csv('boston_housing_data.csv')
b_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     1.269195   13.295257    9.205158    0.140765    1.101175   15.679800
# std      2.399207   23.048697    7.169630    0.312765    1.646991   27.220206
# min      0.000000    0.000000    0.000000    0.000000    0.385000    3.561000
# 25%      0.049443    0.000000    3.440000    0.000000    0.449000    5.961500
# 50%      0.144655    0.000000    6.960000    0.000000    0.538000    6.322500
# 75%      0.819623   18.100000   18.100000    0.000000    0.647000    6.949000
# max      9.966540  100.000000   27.740000    1.000000    7.313000  100.000000
#
#               AGE         DIS         RAD         TAX     PIRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    58.744660    6.173308   78.063241  339.317787   42.614980  332.791107
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(b_data['RM'],b_data['MEDV'])
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.show()

# %%
plt.scatter(b_data['DIS'],b_data['MEDV'])
plt.xlabel('DIS')
plt.ylabel('MEDV')
plt.show()

# %%
plt.scatter(b_data['B'],b_data['MEDV'])
plt.xlabel('B')
plt.ylabel('MEDV')
plt.show()

# %%
import numpy as np
df = pd.read_csv('boston_housing_data.csv')  # 读取数据
x = df['RM']  # 获取某一特征的数据
y = x.index  # 获取标签
# print(y)
x = x.values
# 构建矩阵X和向量y
X = np.matrix(np.column_stack((np.ones(len(x)), x)))
# print(X)
y = np.matrix(y).T

# 最小二乘法
w = (((X.T)*X).I)*(X.T)*y
# print(w)
# 输出预测结果
print("Predictions:", w[0])

# # 使用梯度下降法求解
# # 初始化参数向量theta和学习率alpha
# theta = np.matrix(np.zeros((2, 1)))
# alpha = 0.1
# iteration = 1000
# for i in range(iteration):
#     gradient = (X.T)*(X*theta - y)
#     theta = theta - alpha*gradient
# # 进行预测
# print("Predictions:", theta[0])
# Out:
# Predictions: [[220.93962014]]
